# %% [markdown]
# # **Operações aritméticas**

# %% [markdown]
# Soma

# %%
4 + 6
# Out:
# [1] 10

# %% [markdown]
# Subtração

# %%
4 - 6
# Out:
# [1] -2

# %% [markdown]
# Divisão inteira

# %%
7 %/% 2
# Out:
# [1] 3

# %% [markdown]
# Resto da divisão

# %%
7 %% 2
# Out:
# [1] 1

# %% [markdown]
# Potência

# %%
4 ** 2
# Out:
# [1] 16

# %%
4 ^ 2
# Out:
# [1] 16

# %% [markdown]
# Raiz quadrada

# %%
sqrt(9)
# Out:
# [1] 3

# %% [markdown]
# Ordem de precedência

# %%
4 + (2 * 3)
# Out:
# [1] 10

# %%
(4 + 2) * 3
# Out:
# [1] 18
