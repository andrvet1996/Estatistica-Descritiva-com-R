# %% [markdown]
# Vetor
#
# É uma estrutura de dados básica do R, que permite armazenar um conjunto de valores numéricos ou de caractere sob um mesmo nome. Esses valores podem ser acessados individualmente através de índices.                          Fonte: http://www.estatisticacomr.uff.br/?p=56

# %%
notas <-c(5, 7, 6.5, 9.5, 3.47)
print(notas)

# %% [markdown]
# Ordenar em ordem crescente

# %%
sort(notas)
# Out:
# [1] 3.47 5.00 6.50 7.00 9.50

# %% [markdown]
# Soma

# %%
sum(notas)
# Out:
# [1] 31.47

# %% [markdown]
# Máximo

# %%
max(notas)
# Out:
# [1] 9.5

# %% [markdown]
# Mínimo

# %%
min(notas)
# Out:
# [1] 3.47

# %% [markdown]
# Amplitude

# %%
range(notas)
# Out:
# [1] 3.47 9.50
