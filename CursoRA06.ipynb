# %% [markdown]
# Média aritmética
#
#
# ![image.png](data:image/png;base64,...)

# %%
notas <-c(5, 7, 6.5, 9.5, 3.47)
print(notas)
# Out:
# [1] 5.00 7.00 6.50 9.50 3.47

# %% [markdown]
# Cálculo da média (duas formas)

# %%
sum (notas)
print(sum)

media = sum(notas) / 5
print(media)

# %%
media = mean(notas)
print(media)
